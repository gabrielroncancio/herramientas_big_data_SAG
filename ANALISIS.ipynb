# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv("Empresas_mas_Grandes_del_Pais.csv")

# %%
df.shape
# Out:
# (30000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NIT                     30000 non-null  int64
#  1   RAZÓN SOCIAL            29998 non-null  object
#  2   SUPERVISOR              30000 non-null  object
#  3   REGIÓN                  30000 non-null  object
#  4   DEPARTAMENTO DOMICILIO  30000 non-null  object
#  5   CIUDAD DOMICILIO        30000 non-null  object
#  6   CIIU                    30000 non-null  int64
#  7   MACROSECTOR             30000 non-null  object
#  8   INGRESOS OPERACIONALES  30000 non-null  object
#  9   GANANCIA (PÉRDIDA)      30000 non-null  object
#  10  TOTAL ACTIVOS           30000 non-null  object
#  11  TOTAL PASIVOS           30000 non-null  object
#  12  TOTAL PATRIMONIO        30000 non-null  object
#  13  Año de Corte            30000 non-null  int64
# ...

# %%
df
# Out:
#              NIT                                       RAZÓN SOCIAL  \
# 0      899999068                                      ECOPETROL S.A
# 1      900112515                       REFINERIA DE CARTAGENA S.A.S
# 2      830095213                           ORGANIZACIÓN TERPEL S.A.
# 3      860069804                      CARBONES DEL CERREJON LIMITED
# 4      800021308                                       DRUMMOND LTD
# ...          ...                                                ...
# 29995  800215707                    SERVICIOS Y PROCESOS SERPRO SAS
# 29996  900895431                              TEMPORAL ACTIVA S.A.S
# 29997  900208659                                        DAMIS S.A.S
# 29998  901097082  DISTRIBUCIONES NUEVO HORIZONTE DEL CASANARE S....
# 29999  891224259                                         TEXCOL SAS
#
#             SUPERVISOR                 REGIÓN DEPARTAMENTO DOMICILIO  \
# 0      SUPERFINANCIERA  Bogotá - Cundinamarca            BOGOTA D.C.
# ...

# %%
df.columns
# Out:
# Index(['NIT', 'RAZÓN SOCIAL', 'SUPERVISOR', 'REGIÓN', 'DEPARTAMENTO DOMICILIO',
#        'CIUDAD DOMICILIO', 'CIIU', 'MACROSECTOR', 'INGRESOS OPERACIONALES',
#        'GANANCIA (PÉRDIDA)', 'TOTAL ACTIVOS', 'TOTAL PASIVOS',
#        'TOTAL PATRIMONIO', 'Año de Corte'],
#       dtype='object')

# %%
df.head(21)
# Out:
#           NIT                                       RAZÓN SOCIAL  \
# 0   899999068                                      ECOPETROL S.A
# 1   900112515                       REFINERIA DE CARTAGENA S.A.S
# 2   830095213                           ORGANIZACIÓN TERPEL S.A.
# 3   860069804                      CARBONES DEL CERREJON LIMITED
# 4   800021308                                       DRUMMOND LTD
# 5   890900608                                ALMACENES EXITO S A
# 6   890904996               EMPRESAS PÚBLICAS DE MEDELLÍN E.S.P.
# 7   900156264                                     NUEVA EPS S.A.
# 8   800153993                          COMUNICACIÓN CELULAR S.A.
# 9   900276962                                             D1 SAS
# 10  890100577                                            AVIANCA
# 11  890900943                          COLOMBIANA DE COMERCIO SA
# 12  860063875                                 EMGESA S.A. E.S.P.
# ...

# %%
df.tail(21)
# Out:
#              NIT                                       RAZÓN SOCIAL  \
# 29979  900342562                                    FINLECO BPO SAS
# 29980  830511795                            PASTAS COMARRICO S.A.S.
# 29981  860025492                                        PINAGRO SCA
# 29982  900931706                                  LEAL COLOMBIA SAS
# 29983  900210398                                  ZH INGENIEROS SAS
# 29984  805004030                              UNIVERSAL AVICOLA SAS
# 29985  811044170                            INDUSTRIAS HUMBERT S.A.
# 29986  800191603                  HEALTH SAFETY AND ENVIRONMENT SAS
# 29987  900541887  GFCM COMERCIAL MEXICO, S.A DE C.V., SOFOM, E.N...
# 29988  900945091                        ONCE SEGURIDAD PRIVADA LTDA
# 29989  832009861                              LACTEOS APPENZELL SAS
# 29990  811023441                        SOLUCIONES ADHESIVAS LG SAS
# 29991  802022016                                         FINTRA SAS
# ...

# %%
df.loc[0]
# Out:
# NIT                                     899999068
# RAZÓN SOCIAL                        ECOPETROL S.A
# SUPERVISOR                        SUPERFINANCIERA
# REGIÓN                      Bogotá - Cundinamarca
# DEPARTAMENTO DOMICILIO                BOGOTA D.C.
# CIUDAD DOMICILIO          BOGOTA D.C.-BOGOTA D.C.
# CIIU                                          610
# MACROSECTOR                                MINERO
# INGRESOS OPERACIONALES                    $144.82
# GANANCIA (PÉRDIDA)                         $33.41
# TOTAL ACTIVOS                             $216.85
# TOTAL PASIVOS                             $125.81
# TOTAL PATRIMONIO                           $91.03
# Año de Corte                                 2022
# Name: 0, dtype: object

# %%
df.loc[[0,11,101,1001,2551,5100,8500,9120,9999]]
# Out:
#             NIT                                RAZÓN SOCIAL       SUPERVISOR  \
# 0     899999068                               ECOPETROL S.A  SUPERFINANCIERA
# 11    890900943                   COLOMBIANA DE COMERCIO SA  SUPERSOCIEDADES
# 101   900777972          C.I. TRAFIGURA COAL COLOMBIA S.A.S  SUPERSOCIEDADES
# 1001  900614334                                YILCOQUE SAS  SUPERSOCIEDADES
# 2551  892000401           INVERSIONES CLINICA DEL META S.A.       SUPERSALUD
# 5100  891302008          ESTACION DE SERVICIO LA REYNA LTDA  SUPERSOCIEDADES
# 8500  900199289                     KOOLL IMPORTACIONES SAS  SUPERSOCIEDADES
# 9120  890937740  DISTRIBUIDORA DE LUBRICANTES S.T.M. S.A.S.  SUPERSOCIEDADES
# 9999  900107634                                  UNIFY LTDA  SUPERSOCIEDADES
#
#                      REGIÓN DEPARTAMENTO DOMICILIO           CIUDAD DOMICILIO  \
# 0     Bogotá - Cundinamarca            BOGOTA D.C.    BOGOTA D.C.-BOGOTA D.C.
# ...

# %%
df.REGIÓN.describe()
# Out:
# count                     30000
# unique                        7
# top       Bogotá - Cundinamarca
# freq                      13935
# Name: REGIÓN, dtype: object

# %%
df.SUPERVISOR.describe()
# Out:
# count               30000
# unique                  6
# top       SUPERSOCIEDADES
# freq                26314
# Name: SUPERVISOR, dtype: object

# %%
df.MACROSECTOR.describe()
# Out:
# count        30000
# unique           6
# top       COMERCIO
# freq         10200
# Name: MACROSECTOR, dtype: object

# %%
df["TOTAL ACTIVOS"].describe()
# Out:
# count     30000
# unique      488
# top       $0.01
# freq       6162
# Name: TOTAL ACTIVOS, dtype: object

# %%
df["TOTAL PATRIMONIO"].describe()
# Out:
# count     30000
# unique      406
# top       $0.01
# freq       9309
# Name: TOTAL PATRIMONIO, dtype: object

# %%
df.CIIU.describe()
# Out:
# count    30000.000000
# mean      4604.931967
# std       2359.709994
# min        111.000000
# 25%       2930.000000
# 50%       4659.000000
# 75%       6201.000000
# max       9900.000000
# Name: CIIU, dtype: float64

# %%
# GANANCIA (PÉRDIDA)
df["GANANCIA (PÉRDIDA)"].describe()
# Out:
# count     30000
# unique      190
# top       $0.00
# freq      19061
# Name: GANANCIA (PÉRDIDA), dtype: object

# %%
# DEPARTAMENTO DOMICILIO
df["DEPARTAMENTO DOMICILIO"].describe()
# Out:
# count           30000
# unique             35
# top       BOGOTA D.C.
# freq            11766
# Name: DEPARTAMENTO DOMICILIO, dtype: object

# %%
#TOTAL PASIVOS
df["TOTAL PASIVOS"].describe()
# Out:
# count     30000
# unique      339
# top       $0.01
# freq       9375
# Name: TOTAL PASIVOS, dtype: object

# %%
#CANTIDAD
df["TOTAL PATRIMONIO"].count()
# Out:
# np.int64(30000)

# %%
df["INGRESOS OPERACIONALES"].count()
# Out:
# np.int64(30000)

# %%
# PROMEDIO
df["Año de Corte"].mean()
# Out:
# np.float64(2022.0)

# %%
#PROMEDIO
df.CIIU.mean()
# Out:
# np.float64(4604.931966666667)

# %%
# Desviación Estándar 
df.CIIU.std()
# Out:
# np.float64(2359.709993857996)

# %%
df["INGRESOS OPERACIONALES"].min()
# Out:
# '$0.01'

# %%
df["TOTAL ACTIVOS"].min()
# Out:
# '$0.00'

# %%
df["INGRESOS OPERACIONALES"].max()
# Out:
# '$9.95'

# %%
df["TOTAL ACTIVOS"].max()
# Out:
# '$9.88'

# %%
df["TOTAL PASIVOS"].max()
# Out:
# '$99.87'

# %%
# Mediana 
df.CIIU.median()
# Out:
# np.float64(4659.0)

# %%
# Moda 
df.CIIU.mode()
# Out:
# 0    8610
# Name: CIIU, dtype: int64

# %%
# Percentil 25% 
df.CIIU.quantile(0.25)
# Out:
# np.float64(2930.0)

# %%
# Get the 32 unique values ​​from the DEPARTMENT column
df["DEPARTAMENTO DOMICILIO"].unique()
# Out:
# array(['BOGOTA D.C.', 'BOLIVAR', 'ANTIOQUIA', 'ATLANTICO', 'VALLE',
#        'RISARALDA', 'NARIÑO', 'CAUCA', 'SANTANDER', 'CUNDINAMARCA',
#        'MAGDALENA', 'CALDAS', 'CORDOBA', 'NORTE DE SANTANDER', 'BOYACA',
#        'QUINDIO', 'TOLIMA', 'HUILA', 'SUCRE', 'LA GUAJIRA', 'CESAR',
#        'META', 'SAN ANDRES Y PROVIDENCIA', 'CASANARE', 'CHOCO',
#        'PUTUMAYO', 'CAQUETA', 'ARAUCA', 'GUAVIARE', 'VICHADA', 'AMAZONAS',
#        'GUAINIA', 'VAUPES', 'VALLE DEL CAUCA', 'GUAJIRA'], dtype=object)

# %%
# Get the 1798 unique values ​​of the CIUDAD DOMICILIO column
df["CIUDAD DOMICILIO"].unique()
# Out:
# array(['BOGOTA D.C.-BOGOTA D.C.', 'CARTAGENA-BOLIVAR',
#        'ENVIGADO-ANTIOQUIA', 'MEDELLIN-ANTIOQUIA', 'BOGOTÁ-BOGOTA D.C.',
#        'BARRANQUILLA-ATLANTICO', 'YUMBO-VALLE', 'PEREIRA-RISARALDA',
#        'CALI-VALLE', 'ITAGUI-ANTIOQUIA', 'RIONEGRO-ANTIOQUIA',
#        'PASTO-NARIÑO', 'ZARZAL-VALLE', 'POPAYAN-CAUCA',
#        'BUCARAMANGA-SANTANDER', 'PALMIRA-VALLE', 'TURBACO-BOLIVAR',
#        'SOPO-CUNDINAMARCA', 'COTA -CUNDINAMARCA', 'FUNZA -CUNDINAMARCA',
#        'CHIA-CUNDINAMARCA', 'TOCANCIPA -CUNDINAMARCA',
#        'GIRARDOTA -ANTIOQUIA', 'BARBOSA-ANTIOQUIA',
#        'SANTA MARTA-MAGDALENA', 'FACATATIVA-CUNDINAMARCA',
#        'COPACABANA -ANTIOQUIA', 'MANIZALES-CALDAS', 'BUGA-VALLE',
#        'CIENAGA DE ORO-CORDOBA', 'CAJICA-CUNDINAMARCA',
#        'CUCUTA-NORTE DE SANTANDER', 'LA-ESTRELLA -ANTIOQUIA',
#        'SABANETA -ANTIOQUIA', 'GIRON-SANTANDER', 'SOLEDAD-ATLANTICO',
#        'ALMEIDA-BOYACA-BOYACA', 'FLORIDABLANCA-SANTANDER',
# ...

# %%
# Get the 6 unique values ​​from the MACROSECTOR
df.MACROSECTOR.unique()
# Out:
# array(['MINERO', 'MANUFACTURA', 'COMERCIO', 'SERVICIOS', 'CONSTRUCCIÓN',
#        'AGROPECUARIO'], dtype=object)

# %%
# Get the 6 unique values ​​from the SUPERVISOR
df.SUPERVISOR.unique()
# Out:
# array(['SUPERFINANCIERA', 'SUPERSOCIEDADES', 'SUPERSALUD',
#        'SUPERTRANSPORTE', 'SUPERSERVICIOS', 'SUPERVIGILANCIA'],
#       dtype=object)

# %%
# Get the 7 unique values ​​from the REGION
df.REGIÓN.unique()
# Out:
# array(['Bogotá - Cundinamarca', 'Costa Atlántica', 'Antioquia',
#        'Costa Pacífica', 'Eje Cafetero', 'Centro - Oriente', 'Otros'],
#       dtype=object)

# %%
# Get the unique values ​​of thE TOTAL ACTIVOS column
df["TOTAL ACTIVOS"].unique()
# Out:
# array(['$216.85', '$42.84', '$7.48', '$10.45', '$14.27', '$14.85',
#        '$59.47', '$5.91', '$23.43', '$4.90', '$17.89', '$6.14', '$27.06',
#        '$5.05', '$2.10', '$2.47', '$5.20', '$19.56', '$14.83', '$5.30',
#        '$1.74', '$7.95', '$10.68', '$0.94', '$3.22', '$3.79', '$8.71',
#        '$11.62', '$8.70', '$11.11', '$23.81', '$12.25', '$5.81', '$1.45',
#        '$1.91', '$1.87', '$0.22', '$2.86', '$4.60', '$1.12', '$2.34',
#        '$0.95', '$3.47', '$1.04', '$3.67', '$31.51', '$0.67', '$2.13',
#        '$1.30', '$2.40', '$1.02', '$1.82', '$0.66', '$25.49', '$4.87',
#        '$10.80', '$1.47', '$2.37', '$3.60', '$3.04', '$1.00', '$1.48',
#        '$1.69', '$1.19', '$1.08', '$1.42', '$4.41', '$3.43', '$2.06',
#        '$2.07', '$2.66', '$0.36', '$2.26', '$0.27', '$17.45', '$1.61',
#        '$1.33', '$2.16', '$1.10', '$0.19', '$20.04', '$0.70', '$2.54',
#        '$1.58', '$0.91', '$0.60', '$1.29', '$2.43', '$3.64', '$0.41',
# ...

# %%
# Get the unique values ​​of thE TOTAL PASIVOS column
df["TOTAL PASIVOS"].unique()
# Out:
# array(['$125.81', '$16.48', '$4.47', '$9.00', '$6.34', '$7.62', '$30.24',
#        '$5.43', '$14.67', '$4.75', '$19.33', '$3.96', '$11.89', '$3.98',
#        '$1.87', '$2.39', '$5.10', '$2.35', '$10.07', '$3.28', '$1.27',
#        '$3.36', '$7.53', '$0.91', '$2.81', '$2.34', '$3.83', '$5.53',
#        '$2.07', '$6.63', '$18.24', '$9.46', '$1.82', '$1.37', '$1.41',
#        '$1.62', '$0.79', '$2.42', '$2.53', '$1.48', '$2.04', '$1.55',
#        '$0.65', '$0.63', '$11.01', '$0.48', '$1.40', '$0.78', '$2.20',
#        '$1.23', '$0.45', '$7.04', '$2.06', '$5.61', '$1.00', '$0.57',
#        '$1.08', '$1.65', '$1.07', '$0.55', '$4.74', '$0.64', '$0.25',
#        '$0.68', '$0.76', '$4.39', '$1.97', '$1.11', '$1.57', '$1.12',
#        '$1.72', '$1.04', '$6.15', '$0.85', '$1.05', '$0.02', '$0.16',
#        '$3.07', '$0.37', '$1.34', '$0.30', '$0.58', '$1.61', '$1.49',
#        '$0.32', '$0.75', '$5.49', '$0.62', '$1.20', '$0.38', '$0.35',
# ...

# %%
# Get the unique values ​​of thE INGRESOS OPERACIONALES column
df["INGRESOS OPERACIONALES"].unique()
# Out:
# array(['$144.82', '$27.86', '$23.60', '$16.39', '$15.27', '$15.13',
#        '$15.07', '$14.78', '$14.63', '$13.96', '$11.44', '$11.14',
#        '$10.87', '$9.66', '$9.30', '$8.72', '$8.62', '$8.53', '$7.86',
#        '$7.78', '$7.76', '$7.20', '$6.96', '$6.57', '$6.21', '$5.99',
#        '$5.52', '$5.50', '$5.15', '$4.92', '$4.82', '$4.72', '$4.64',
#        '$4.47', '$4.42', '$4.34', '$2.51', '$4.28', '$4.14', '$4.08',
#        '$4.05', '$3.97', '$3.90', '$3.73', '$3.70', '$3.59', '$3.58',
#        '$3.57', '$3.52', '$3.50', '$3.44', '$3.37', '$3.32', '$3.25',
#        '$3.09', '$2.82', '$2.78', '$2.77', '$2.76', '$2.75', '$2.73',
#        '$2.67', '$2.64', '$2.63', '$2.62', '$2.60', '$2.55', '$2.53',
#        '$2.52', '$2.49', '$2.48', '$2.47', '$2.43', '$2.30', '$2.28',
#        '$2.27', '$2.26', '$2.25', '$2.21', '$2.16', '$2.11', '$2.10',
#        '$2.09', '$2.05', '$2.02', '$2.00', '$1.99', '$1.96', '$1.95',
# ...

# %%
# Get the unique values ​​of thE GANANCIA (PÉRDIDA) column
df["GANANCIA (PÉRDIDA)"].unique()
# Out:
# array(['$33.41', '$2.19', '$0.33', '$6.05', '$2.16', '$0.10', '$3.04',
#        '$0.01', '$1.79', '$0.29', '-$0.80', '$0.34', '$2.86', '$0.88',
#        '-$0.14', '-$0.30', '-$0.23', '$4.58', '-$0.07', '$0.14', '$0.05',
#        '$2.84', '$1.72', '-$0.03', '$0.17', '$0.31', '$2.49', '$1.62',
#        '$0.47', '$1.23', '$0.78', '-$0.01', '-$0.06', '-$0.13', '$0.03',
#        '-$0.15', '$1.21', '$0.12', '$0.04', '-$0.70', '$1.29', '$0.19',
#        '$0.25', '$2.85', '$0.15', '$0.07', '$0.11', '$0.06', '$0.27',
#        '$0.00', '$0.53', '$2.28', '$0.08', '$0.98', '$0.40', '$0.16',
#        '-$0.04', '-$0.47', '$0.38', '$0.20', '$0.09', '$0.28', '-$0.25',
#        '$0.13', '-$0.42', '$0.37', '$0.02', '$2.31', '$0.97', '$2.54',
#        '$0.30', '$1.12', '-$0.19', '$0.32', '$0.49', '-$0.05', '$0.45',
#        '-$0.36', '-$0.09', '$0.18', '-$0.02', '$1.18', '-$0.16', '$0.36',
#        '-$0.27', '$0.23', '$0.24', '$1.34', '$0.22', '-$0.00', '$0.35',
# ...
